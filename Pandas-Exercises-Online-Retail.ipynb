# %% [markdown]
# # Online Retails Purchase

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [Online_Retail.csv](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Visualization/Online_Retail/Online_Retail.csv) from the folder.

# %%
online_rt = pd.read_csv("D:/Data/Pandas Basic Exercises/2. Pandas Basic Exercises/Exercise Data Files/Pandas Exercise Online Retail files/Online_Retail.csv")

# %% [markdown]
# ### Step 3. Assign it to a variable called online_rt

# %%
online_rt
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### Step 4. Create a histogram with the 10 countries that have the most 'Quantity' ordered except UK

# %%
a=online_rt.groupby(['Country'])['Quantity'].max()
a.sort_values()
a=a.tail(11)
a=pd.DataFrame(a)
a=a.T
a=a.drop(columns='United Kingdom')
a.plot(kind='hist');

# %% [markdown]
# ### Step 5.  Exclude negative Quatity entries

# %%
online_rt['Quantity'][online_rt['Quantity']<0]=0
# online_rt['Quantity'].unique()
# Out:
# <ipython-input-8-52daf7a2a60d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   online_rt['Quantity'][online_rt['Quantity']<0]=0

# %% [markdown]
# ### Step 6. Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries

# %%
x=online_rt['Quantity']/online_rt['UnitPrice']
online_rt['a']=pd.Series(x)
# online_rt['a']
c=online_rt.groupby(['Country'])['a','CustomerID'].max()
c
c.sort_values('a')
# c.tail(3)
# c.plot(kind='scatter' ,x='a',y='CustomerID')
# Out:
# <ipython-input-16-ed1ba953ec45>:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   c=online_rt.groupby(['Country'])['a','CustomerID'].max()
#                                 a  CustomerID
# Country
# Brazil                  28.235294     12769.0
# Saudi Arabia            28.571429     12565.0
# Lithuania               28.800000     15332.0
# Lebanon                 43.636364     12764.0
# European Community      43.636364     15108.0
# Bahrain                 76.800000     12355.0
# United Arab Emirates   110.769231     17829.0
# USA                    110.769231     12733.0
# Malta                  123.076923     17828.0
# Unspecified            165.517241     16320.0
# Greece                 171.428571     17508.0
# Iceland                230.769231     12347.0
# Czech Republic         248.275862     12781.0
# Poland                 252.631579     12816.0
# ...

# %%
online_rt
# Out:
# Country
# Australia                       inf
# Austria                  800.000000
# Bahrain                   76.800000
# Belgium                  850.000000
# Brazil                    28.235294
# Canada                  1371.428571
# Channel Islands          626.153846
# Cyprus                  1371.428571
# Czech Republic           248.275862
# Denmark                  355.555556
# EIRE                            inf
# European Community        43.636364
# Finland                  496.551724
# France                          inf
# Germany                         inf
# Greece                   171.428571
# Hong Kong                496.551724
# Iceland                  230.769231
# Israel                   800.000000
# Italy                    369.230769
# Japan                   2742.857143
# Lebanon                   43.636364
# Lithuania                 28.800000
# Malta                    123.076923
# Netherlands                     inf
# Norway                          inf
# ...
